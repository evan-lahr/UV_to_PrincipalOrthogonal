# %%
import pandas as pd
import current_rotation
import matplotlib as plt
import numpy as np

#define data
sn21=pd.read_csv('../data/sn21.csv')

#rotate UV components
current_rotation.rot_principal(sn21['U'],sn21['V'])
# Out:
# (0        734.793522
#  1        373.640806
#  2        117.701740
#  3        217.410890
#  4        156.144953
#              ...
#  80125     56.322479
#  80126     72.924339
#  80127     59.524873
#  80128     58.232741
#  80129     59.791820
#  Length: 80130, dtype: float64,
#  0        233.084707
#  1        584.041564
#  2          1.516719
#  3       -135.582097
#  4        314.802722
#              ...
#  80125   -111.592017
#  80126   -102.406254
#  80127   -106.928899
#  80128    -72.587519
#  80129    -59.075699
#  Length: 80130, dtype: float64)
